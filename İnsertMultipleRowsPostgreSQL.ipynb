# %%
import psycopg2 as db
from faker import Faker

# %%
fake=Faker()

# %%
data=[]

# %%
i=2

# %%
for r in range(1000):
    data.append((i,fake.name(),fake.street_address(),fake.city(),fake.zipcode()))
    i+=1
data_for_db=tuple(data)

# %%
conn_string="dbname='spotifydb' host='localhost' user='postgres' password='Pa55w.rd'"

# %%
conn=db.connect(conn_string)

# %%
cur=conn.cursor()

# %%
query='insert into users (id,name,street,city,zip) values(%s,%s,%s,%s,%s)'

# %%
print(cur.mogrify(query,data_for_db[1]))
# Out:
# b"insert into users (id,name,street,city,zip) values(3,'Donna Salazar','9461 Nelson Estate','Hodgefurt','05520')"

# %%
cur.executemany(query,data_for_db)

# %%
conn.commit()

# %%
query2='select * from users'

# %%
cur.execute(query2)

# %%
print(cur.fetchall())
# Out:
# [('Big Bird', 1, 'Sesame Street', 'Fakeville', '12345'), ('Andrew Moore', 2, '4485 Robert Brooks', 'Patricktown', '08535'), ('Donna Salazar', 3, '9461 Nelson Estate', 'Hodgefurt', '05520'), ('Jason Hobbs', 4, '74478 Alicia Pike Apt. 148', 'Port Jamiefurt', '89637'), ('Amanda Rodriguez', 5, '8512 Diaz Summit Suite 948', 'West David', '75971'), ('Deborah Little', 6, '37342 Sanchez Turnpike', 'Williamsborough', '77101'), ('Gina Taylor', 7, '90343 Bryan Mountains Suite 957', 'Powellside', '12342'), ('Stephanie Johnson', 8, '6319 Jones Groves', 'Welchmouth', '41358'), ('Diana Young', 9, '6622 Delacruz Haven', 'Mirandamouth', '03464'), ('Kara Larson', 10, '3547 Barbara Trace Suite 168', 'Michellebury', '49494'), ('Denise Freeman', 11, '090 Watts Unions', 'Allenhaven', '56097'), ('Brianna Hubbard', 12, '8448 Charles Isle Apt. 995', 'Matthewside', '58061'), ('Ricardo Carter', 13, '33815 Johnson Passage', 'North Joshualand', '88231'), ('Carrie Brennan', 14, '72690 Brent Mills', 'North Cathy', '19028'), ('Christine Johnson', 15, '7532 Clark Common Suite 773', 'Myersbury', '36053'), ('Brandon Rojas', 16, '67778 Cunningham Burg Suite 222', 'Brownville', '57306'), ('Samuel Booker', 17, '7286 Carlson Trace', 'West Stephenburgh', '79316'), ('Stephanie Patrick', 18, '64443 Gerald Bypass Suite 264', 'New Tina', '23824'), ('Ricky Lawrence', 19, '19664 Graves Stream Suite 627', 'Jasonhaven', '50946'), ('Kenneth Santos', 20, '6483 Camacho Greens', 'Lake Robert', '57983'), ('Crystal Smith', 21, '78217 Wilkinson Meadow', 'Turnerview', '79628'), ('Jimmy Morgan', 22, '22533 Veronica Fields Apt. 197', 'East Catherine', '09483'), ('Charles Harrison', 23, '97752 James Groves Apt. 693', 'Markborough', '22849'), ('Sara Bowman', 24, '98764 Steven Port Suite 729', 'East Darren', '08233'), ('Kristen Schwartz', 25, '9694 Wilson Trail', 'Mcguireland', '26376'), ('Cody Watson', 26, '432 Moore Street', 'Edwardborough', '87462'), ('Jennifer Mason', 27, '4504 Davidson Run', 'Jessicafort', '22348'), ('Lori Chavez', 28, '284 Galloway Overpass Suite 514', 'North Chris', '99483'), ('Sandra Edwards', 29, '2421 Griffin Dale', 'East James', '72292'), ('Andrew Lee', 30, '37029 Theodore Highway', 'South Robinburgh', '45539'), ('Mark Brown', 31, '89182 Wagner Valleys Apt. 535', 'Greeneburgh', '07143'), ('Samantha Herman', 32, '638 Charles Underpass Suite 242', 'Emilyfurt', '48727'), ('Christopher Mitchell', 33, '5035 Thomas Centers Apt. 593', 'Marthachester', '37757'), ('Michael Wilkinson', 34, '493 Reynolds Park', 'Robbinston', '35778'), ('Angela Carson', 35, '567 Zimmerman Cove', 'North Larry', '97300'), ('Aaron Bailey', 36, '060 Ann Estate Apt. 331', 'East Robert', '86344'), ('Samantha Gonzalez', 37, '70849 Dillon Springs Suite 759', 'New Sharonchester', '33079'), ('Matthew Drake', 38, '426 Berry Plaza', 'East Thomas', '44104'), ('Daniel Decker', 39, '41828 Jason Inlet Suite 468', 'Christyfort', '34253'), ('Jared Baldwin', 40, '87400 Alexander Row Apt. 893', 'North Kimstad', '34095'), ('John Brown', 41, '435 Jones Trail', 'New Katieborough', '69069'), ('Carol Gallegos', 42, '6138 Murphy Pine', 'Jonesstad', '55662'), ('Joshua Pearson', 43, '52290 Morgan Points Apt. 519', 'South Debbie', '98604'), ('Charles Andrade', 44, '0762 Sharp Overpass', 'Port Robert', '41763'), ('Mitchell Duarte', 45, '8977 Jesse Mews', 'North Jenniferside', '51544'), ('Justin Frank', 46, '085 Turner Summit Suite 784', 'Ayerstown', '62100'), ('Paula Bruce', 47, '57127 Vanessa Squares', 'Hawkinsland', '06366'), ('Michael Stone', 48, '46321 Valerie Rapids', 'Serranoland', '74028'), ('Cheryl Stanley', 49, '710 Jenkins Ranch', 'East Patriciahaven', '66887'), ('Mr. Brian Harrison', 50, '45061 Jason Club Apt. 546', 'New Rebeccatown', '29633'), ('Justin Ruiz', 51, '968 Zachary Road', 'Joychester', '70853'), ('Julia Ruiz', 52, '1818 Garcia Plaza Suite 480', 'West Tony', '02767'), ('Eric Daniels', 53, '68985 Christopher Court', 'Frankfurt', '52909'), ('Robert Hicks', 54, '5609 Richard Tunnel', 'New Ashleyshi ...
